# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import numpy
import seaborn as sns 


credit = pd.read_csv('C5-T1-credit1.csv', header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
credit.isnull()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# 5      False      False  False      False     False  False  False  False
# 6      False      False  False      False     False  False  False  False
# 7      False      False  False      False     False  False  False  False
# 8      False      False  False      False     False  False  False  False
# 9      False      False  False      False     False  False  False  False
# 10     False      False  False      False     False  False  False  False
# 11     False      False  False      False     False  False  False  False
# ...

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
# checking for missing values 
credit.isnull().values.any()
# Out:
# False

# %%
credit.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
x = credit['PAY_0']
y = credit['PAY_2']
plt.scatter(x,y)
plt.show()

# %%
x = credit['PAY_0']
y = credit['PAY_2']
z = credit['AGE']
d = credit['default payment next month']
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
import matplotlib
matplotlib.pyplot.bar(d,z)
# Out:
# <BarContainer object of 30000 artists>

# %%
header = credit.dtypes.index
print(header)
A = credit['BILL_AMT1']

plt.boxplot(A,0,'gD')
plt.show()
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
type(credit)
# Out:
# pandas.core.frame.DataFrame

# %%
credit.shape
# Out:
# (30000, 25)

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
type(credit.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#calculate covariance

covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
# number of clients per default payment
credit.groupby('default payment next month')['default payment next month'].count()
credit.groupby('default payment next month')['default payment next month'].count()
# Out:
# default payment next month
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
sns.factorplot('default payment next month', data=credit, kind='count', aspect=1.5)

# %%
credit.groupby(['SEX', 'default payment next month'])['SEX'].count()
# Out:
# SEX  default payment next month
# 1    0                              9015
#      1                              2873
# 2    0                             14349
#      1                              3763
# Name: SEX, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
credit.groupby('SEX').sum().plot(kind = 'bar')

# %%
mynewdf = credit[['SEX', 'default payment next month']].copy()

# %%
mynewdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 2 columns):
# SEX                           30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(2)
# memory usage: 468.8 KB

# %%
mynewdf.groupby('SEX').sum().plot(kind = 'bar')

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
# Crating a subset for those who defaulted their loan

# Number of customers who defaulted their loans:

defaulted = credit[credit['default payment next month'] == 1]
len(defaulted)
# Out:
# 6636

# %%
# Number of customers who did not defaulted their loans:

loyal = credit[credit['default payment next month'] == 0]
len(loyal)
# Out:
# 23364

# %%
# percentage of customers who defaulted their loans. 

percentage = round(len(defaulted)/len(loyal)*100)
percentage
# Out:
# 28

# %%
print(percentage ,  '% of the customers defaulted their loans')
# Out:
# 28 % of the customers defaulted their loans

# %%
defaulted.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
defaulted.shape
# Out:
# (6636, 25)

# %%
# # of customers who defautlted their loan grouped by gender
defaulted['SEX'].value_counts()
# Out:
# 2    3763
# 1    2873
# Name: SEX, dtype: int64

# %%
# education level 2 has the highest number of male and femal defaulters 

defaulted['EDUCATION'].value_counts()
# Out:
# 2    3330
# 1    2036
# 3    1237
# 5      18
# 6       8
# 4       7
# Name: EDUCATION, dtype: int64

# %%
len(credit[credit['EDUCATION'] == 2])
# Out:
# 14030

# %%
defaulted.groupby(["SEX", "EDUCATION"]).size()
# Out:
# SEX  EDUCATION
# 1    1             906
#      2            1408
#      3             545
#      4               4
#      5               6
#      6               4
# 2    1            1130
#      2            1922
#      3             692
#      4               3
#      5              12
#      6               4
# dtype: int64

# %%
## age 
defaulted["AGE"].value_counts()
# Early to mid career customers are more likely to default
# Out:
# 27    313
# 29    313
# 25    302
# 24    300
# 28    286
# 30    274
# 36    254
# 26    253
# 23    247
# 34    231
# 37    229
# 31    229
# 35    226
# 32    225
# 33    215
# 39    199
# 38    194
# 40    187
# 42    185
# 41    185
# 22    169
# 44    162
# 46    157
# 43    150
# 47    120
# 49    119
# 45    116
# 48    104
# 50    101
# 51     88
# 52     78
# 53     74
# 55     57
# 54     56
# 56     49
# 58     31
# 57     27
# 60     23
# 59     21
# 61     21
# 21     14
# 64      9
# 63      8
# 62      7
# 66      7
# 65      5
# 67      5
# 73      3
# 69      3
# 70      2
# 68      1
# 72      1
# 75      1
# Name: AGE, dtype: int64

# %%
# Marital Status
defaulted['MARRIAGE'].value_counts()

# Look out for singles!
# Out:
# 2    3341
# 1    3206
# 3      84
# 0       5
# Name: MARRIAGE, dtype: int64

# %%
defaulted.groupby(["MARRIAGE", "AGE"]).size()
# Out:
# MARRIAGE  AGE
# 0         26       1
#           27       1
#           41       1
#           42       1
#           44       1
# 1         21       2
#           22      15
#           23      33
#           24      39
#           25      46
#           26      43
#           27      74
#           28      69
#           29      66
#           30     101
#           31      82
#           32     101
#           33      97
#           34     120
#           35     145
#           36     140
#           37     152
#           38     134
#           39     138
#           40     130
#           41     136
#           42     130
#           43     107
#           44     105
#           45      97
#                 ...
# 3         26       1
#           28       2
#           29       1
#           30       2
#           31       1
#           33       1
#           34       2
#           35       3
#           36       1
#           37       2
#           38       1
# ...

# %%
defaulted['bill'] = defaulted['BILL_AMT1'] + defaulted['BILL_AMT2'] + defaulted['BILL_AMT3'] + defaulted['BILL_AMT4'] + defaulted['BILL_AMT5'] + defaulted['BILL_AMT6']
defaulted['bill']
# Out:
# 0           7704
# 1          17077
# 13        338685
# 16        106161
# 21          1896
# 22        265475
# 23         26965
# 26          -394
# 31        151869
# 38           780
# 45             0
# 46         79328
# 47          9837
# 50        229012
# 60        109699
# 62        157674
# 63         57884
# 65        469636
# 66         22852
# 71        362152
# 78        149186
# 79             0
# 82        143566
# 86          3510
# 90        862167
# 99         93217
# 103       205366
# 115       117660
# 117        99022
# 120       290245
#           ...
# 29885     275830
# 29894      14392
# 29896     421293
# 29897     457362
# 29899     881084
# 29900      16809
# 29904     342865
# 29905     110339
# 29907     376199
# 29908          0
# 29911       2282
# 29917     149098
# 29919      16186
# 29920     322781
# 29921    1303031
# 29929      12628
# 29932     723908
# 29935     204942
# 29942      11688
# 29944     271430
# 29966     363373
# ...

# %%
# education and loan

defaulted.pivot_table('default payment next month','EDUCATION', aggfunc=len, margins=True)
# Out:
#            default payment next month
# EDUCATION
# 1                                2036
# 2                                3330
# 3                                1237
# 4                                   7
# 5                                  18
# 6                                   8
# All                              6636

# %%
credit['SEX'] = credit['SEX'].astype('category')
credit['EDUCATION'] = credit['EDUCATION'].astype('category')
credit['default payment next month'] = credit['default payment next month'].astype('category')
credit['MARRIAGE'] = credit['MARRIAGE'].astype('category')

# %%
credit.pivot_table('MARRIAGE', 'SEX', 'default payment next month', aggfunc=len)
# Out:
# default payment next month      0     1
# SEX
# 1                            9015  2873
# 2                           14349  3763

# %%
credit['AGE'].hist(bins=50)

# %%
# renaming the yvariable to get rid of the spaces 
credit = credit.rename(columns=lambda x: x.replace('default payment next month', 'defaulted'))

# %%
table = pd.crosstab(index=[credit.defaulted, credit.EDUCATION], columns=[credit.SEX,credit.MARRIAGE])

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'defaulted'],
#       dtype='object')

# %%
# Distribution of age with an overlay of defaulted
age = credit['AGE']
age_dist = sns.distplot(age)
age_dist.set_title("Distribution of customers' Ages")
# Out:
# Text(0.5, 1.0, "Distribution of customers' Ages")

# %%
# education 

education = credit['EDUCATION']
edu_dist = sns.distplot(education)

# %%
credit['EDUCATION'].hist()

# %%
# Lets have a look at the first 10 rows of the data frame
credit[:10]
# Out:
#    ID  LIMIT_BAL SEX EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  ...  \
# 0   1      20000   2         2        1   24      2      2     -1     -1  ...
# 1   2     120000   2         2        2   26     -1      2      0      0  ...
# 2   3      90000   2         2        2   34      0      0      0      0  ...
# 3   4      50000   2         2        1   37      0      0      0      0  ...
# 4   5      50000   1         2        1   57     -1      0     -1      0  ...
# 5   6      50000   1         1        2   37      0      0      0      0  ...
# 6   7     500000   1         1        2   29      0      0      0      0  ...
# 7   8     100000   2         2        2   23      0     -1     -1      0  ...
# 8   9     140000   2         3        1   28      0      0      2      0  ...
# 9  10      20000   1         3        2   35     -2     -2     -2     -2  ...
#
#    BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# ...

# %%
sns.factorplot('EDUCATION', data=credit, kind='count', hue='defaulted', order=[0,1,2,3,4,5,6])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
credit['SEX'].value_counts()
credit['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID           30000 non-null int64
# LIMIT_BAL    30000 non-null int64
# SEX          30000 non-null category
# EDUCATION    30000 non-null category
# MARRIAGE     30000 non-null category
# AGE          30000 non-null int64
# PAY_0        30000 non-null int64
# PAY_2        30000 non-null int64
# PAY_3        30000 non-null int64
# PAY_4        30000 non-null int64
# PAY_5        30000 non-null int64
# PAY_6        30000 non-null int64
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# PAY_AMT6     30000 non-null int64
# ...

# %%
credit[['EDUCATION', 'SEX']].head()
# Out:
#   EDUCATION SEX
# 0         2   2
# 1         2   2
# 2         2   2
# 3         2   2
# 4         2   1

# %%
#feature engineering:
t = [0,4,5,6]
for i in credit['EDUCATION']:
    if (i in t):
        i = 7
    else:
        continue

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'defaulted'],
#       dtype='object')

# %%
len(credit['SEX'])
# Out:
# 30000

# %%
len(m)
# Out:
# 11888

# %%
len(f)
# Out:
# 18112

# %%
limit_balance = credit['LIMIT_BAL']
bal_dis = sns.distplot(limit_balance)

# %%
max(limit_balance)
# Out:
# 1000000

# %%
min(limit_balance)
# Out:
# 10000

# %%
len(defaulted)
# Out:
# 6636
